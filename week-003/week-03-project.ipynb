# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 3 - Project</h1>
# </div>
#
#
# # Cleaning up data.
#
# We've got some messy data we need to fix. Using loops and other things we've learned, take the original data and convert it to the format we need.
#
# Show all work. Make sure to clean up notebook and `Kernel -> Restart and Clear All Work` before you submit. We should be able to run your notebook from top to bottom and it should give us the expected output.
#
# If someone changes the data, it should still return the same sort of output.
#
#
#
#
# This is what we have:
# ```python
# [['Open','High','Low','Volume','Close'],
# [828.659973,833.450012,828.349976,1247700,831.659973],
# [823.02002,828.070007,821.655029,1597800,828.070007],
# [819.929993,824.400024,818.97998,1281700,824.159973],
# [819.359985,823,818.469971,1304000,818.97998],
# [819,823,816,1053600,820.450012],
# [816,820.958984,815.48999,1198100,819.23999],
# [811.700012,815.25,809.780029,1129100,813.669983],
# [809.51001,810.659973,804.539978,989700,809.559998],
# [807,811.840027,803.190002,1155300,808.380005],
# [803.98999,810.5,801.780029,1235200,806.969971],
# [799.700012,801.669983,795.25,1174200,801.340027],
# [802.98999,806,800.369995,1460400,801.48999],
# [793.799988,802.700012,792,1525800,798.530029],
# [799.679993,801.190002,791.190002,2023300,795.695007],
# [796.859985,801.25,790.52002,2143500,],]
# ```
#
# And this is what we need:
# ```python
# {
# 'Open': []
# 'High': []
# 'Low': []
# 'Volume': []
# 'Close': []
# }
# ```

# %%
# the \ tells python the line conts. below
list_of_data = \
[['Open','High','Low','Volume','Close'],
[828.659973,833.450012,828.349976,1247700,831.659973],
[823.02002,828.070007,821.655029,1597800,828.070007],
[819.929993,824.400024,818.97998,1281700,824.159973],
[819.359985,823,818.469971,1304000,818.97998],
[819,823,816,1053600,820.450012],
[816,820.958984,815.48999,1198100,819.23999],
[811.700012,815.25,809.780029,1129100,813.669983],
[809.51001,810.659973,804.539978,989700,809.559998],
[807,811.840027,803.190002,1155300,808.380005],
[803.98999,810.5,801.780029,1235200,806.969971],
[799.700012,801.669983,795.25,1174200,801.340027],
[802.98999,806,800.369995,1460400,801.48999],
[793.799988,802.700012,792,1525800,798.530029],
[799.679993,801.190002,791.190002,2023300,795.695007],
[796.859985,801.25,790.52002,2143500,],]

import hashlib;print("list_of_data is correct" if hashlib.md5(str(list_of_data).encode()).hexdigest() == '06d2e9f1606fd8f0d79d3c13ccfe948d' else "list_of_data is incorrect")
# Out:
# list_of_data is correct

# %%
project_dict = {}
for data in range(len(list_of_data)):
    if data == 0:
        for key in list_of_data[data]:
            if type(key) == str:
                project_dict[key] = []

# %%
for title in range(len(list_of_data)):
    for l in range(len(list_of_data[title])):
        if title > 0:
            project_dict[list_of_data[0][l]].append(list_of_data[title][l])
# Out:
# [828.659973, 833.450012, 828.349976, 1247700, 831.659973] 1 0
# [828.659973, 833.450012, 828.349976, 1247700, 831.659973] 1 1
# [803.98999, 810.5, 801.780029, 1235200, 806.969971] 10 2
# [803.98999, 810.5, 801.780029, 1235200, 806.969971] 10 3
# [803.98999, 810.5, 801.780029, 1235200, 806.969971] 10 4
# [799.700012, 801.669983, 795.25, 1174200, 801.340027] 11 0
# [799.700012, 801.669983, 795.25, 1174200, 801.340027] 11 1
# [799.700012, 801.669983, 795.25, 1174200, 801.340027] 11 2
# [799.700012, 801.669983, 795.25, 1174200, 801.340027] 11 3
# [799.700012, 801.669983, 795.25, 1174200, 801.340027] 11 4
# [802.98999, 806, 800.369995, 1460400, 801.48999] 12 0
# [802.98999, 806, 800.369995, 1460400, 801.48999] 12 1
# [802.98999, 806, 800.369995, 1460400, 801.48999] 12 2
# [802.98999, 806, 800.369995, 1460400, 801.48999] 12 3
# [802.98999, 806, 800.369995, 1460400, 801.48999] 12 4
# [793.799988, 802.700012, 792, 1525800, 798.530029] 13 0
# [793.799988, 802.700012, 792, 1525800, 798.530029] 13 1
# [793.799988, 802.700012, 792, 1525800, 798.530029] 13 2
# [793.799988, 802.700012, 792, 1525800, 798.530029] 13 3
# [793.799988, 802.700012, 792, 1525800, 798.530029] 13 4
# [799.679993, 801.190002, 791.190002, 2023300, 795.695007] 14 0
# [799.679993, 801.190002, 791.190002, 2023300, 795.695007] 14 1
# [799.679993, 801.190002, 791.190002, 2023300, 795.695007] 14 2
# [799.679993, 801.190002, 791.190002, 2023300, 795.695007] 14 3
# [799.679993, 801.190002, 791.190002, 2023300, 795.695007] 14 4
# [796.859985, 801.25, 790.52002, 2143500] 15 0
# [796.859985, 801.25, 790.52002, 2143500] 15 1
# [796.859985, 801.25, 790.52002, 2143500] 15 2
# [796.859985, 801.25, 790.52002, 2143500] 15 3

# %%
project_dict
# Out:
# {'Open': [828.659973,
#   823.02002,
#   819.929993,
#   819.359985,
#   819,
#   816,
#   811.700012,
#   809.51001,
#   807,
#   803.98999,
#   799.700012,
#   802.98999,
#   793.799988,
#   799.679993,
#   796.859985],
#  'High': [833.450012,
#   828.070007,
#   824.400024,
#   823,
#   823,
#   820.958984,
#   815.25,
#   810.659973,
#   811.840027,
#   810.5,
#   801.669983,
#   806,
#   802.700012,
#   801.190002,
#   801.25],
#  'Low': [828.349976,
#   821.655029,
#   818.97998,
#   818.469971,
#   816,
#   815.48999,
#   809.780029,
#   804.539978,
#   803.190002,
#   801.780029,
#   795.25,
#   800.369995,
#   792,
#   791.190002,
#   790.52002],
#  'Volume': [1247700,
#   1597800,
#   1281700,
#   1304000,
#   1053600,
#   1198100,
#   1129100,
#   989700,
#   1155300,
#   1235200,
#   1174200,
#   1460400,
#   1525800,
#   2023300,
#   2143500],
#  'Close': [831.659973,
#   828.070007,
#   824.159973,
#   818.97998,
#   820.450012,
#   819.23999,
#   813.669983,
#   809.559998,
#   808.380005,
#   806.969971,
#   801.340027,
#   801.48999,
#   798.530029,
#   795.695007]}
